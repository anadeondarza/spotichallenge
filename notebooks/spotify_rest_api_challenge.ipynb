# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# imports
import pandas as pd
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# generate token with a POST request

client_id = 'bd3fd1065cf04a24ba703cbcc5648d29'
client_secret = 'e060152a420247dda45b7bd00f6cfdf1'
auth_url = 'https://accounts.spotify.com/api/token' #endpoint para generar el token

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

#no es.get es .post, es una accion contra el servidor que nos va a devolver el token. Por eso es .post
# hay dos argumento, el segundo elemento es un diccionario (segundo argumento es el header)
# endpoint + argumentos + headers (es lo que tienes para trabajar con las APIS)

# %%
auth_response
# Out:
# {'access_token': 'BQC2IiLJhjg7WtVgRNAYk0IOCXEoXDgUfbVe1z8mIvUepIxjU_tLsL3-pPVxBXxdFg8lSljK2LbmpdzdX6krgqwomezxhIfiHquMPitwVj0m6mRna30',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQC2IiLJhjg7WtVgRNAYk0IOCXEoXDgUfbVe1z8mIvUepIxjU_tLsL3-pPVxBXxdFg8lSljK2LbmpdzdX6krgqwomezxhIfiHquMPitwVj0m6mRna30',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_url` (i.e.: End-point), parameters and `headers` for your __GET__ operations

# %%
# setting the main variables

base_url = 'https://api.spotify.com/v1' #base del endpoint v1:version 1
parameneter = '/7ltDVBr6mKbRvohxheJ9h1'
related = '/related-artists'
track = '/top-tracks'
resource = '/artists'   # un parámetro
header = {'Authorization': 'Bearer {token}'.format(token=access_token)} #utilizamos otro hearder diferente, un diccionario.

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need
#
# __Here you have the different artists to start with:__
#
# _Option 1:_ 711MCceyCBcFnzjGY4Q7Un
#
# _Option 2:_ 5gs3QMiBgkUgNofeA16Awv
#
# _Option 3:_ 1ZcvF2meiXi5UPDJWxrKR5
#
# _Option 4:_ 0HSGpDMeXaEmH5aUIHjnBF
#
# _Option 5:_ 5TYxZTjIPqKM8K8NuP9woO
#
# _Option 6:_ 36QJpDe2go2KgaRleHCDTp
#
# _Option 7:_ 3qm84nBOXUEQ2vnTfUTTFC
#
# _Option 8:_ 4NJhFmfw43RLBLjQvxDuRS
#
# _Option 9:_ 0L8ExT028jH3ddEcZwqJJ5
#
# _Option 10:_ 1vCWHaC5f2uS3yhpwWbIA6
#
# _Option 11:_ 1dfeR4HaWDbWqFHLkxsg1d
#
# _Option 12:_ 6ogn9necmbUdCppmNnGOdi

# %%
# your code
# 100 canciones 
# headers: es algo propia de la API de Spotify, por eso lo meto. Lo especifico porque como puedo meter otro parámetros para que quede claro.

response = requests.get(base_url + resource + parameneter, headers = header).json()
response
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#  'followers': {'href': None, 'total': 5474716},
#  'genres': ['r&b en espanol'],
#  'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#  'id': '7ltDVBr6mKbRvohxheJ9h1',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebd7bb678bef6d2f26110cae49',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174d7bb678bef6d2f26110cae49',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178d7bb678bef6d2f26110cae49',
#    'width': 160}],
#  'name': 'ROSALÍA',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}

# %%
response1 = requests.get(base_url + resource + parameneter + related, headers = header).json()
response1
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Ces1OJeGOVGcUB0wPaPXJ'},
#    'followers': {'href': None, 'total': 469643},
#    'genres': ['latin alternative',
#     'latin hip hop',
#     'rap latina',
#     'spanish hip hop'],
#    'href': 'https://api.spotify.com/v1/artists/3Ces1OJeGOVGcUB0wPaPXJ',
#    'id': '3Ces1OJeGOVGcUB0wPaPXJ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb5296ee9862de29ee24a1276f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051745296ee9862de29ee24a1276f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1785296ee9862de29ee24a1276f',
#      'width': 160}],
#    'name': 'Mala Rodríguez',
#    'popularity': 57,
#    'type': 'artist',
#    'uri': 'spotify:artist:3Ces1OJeGOVGcUB0wPaPXJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4bJh7sMPcVRiqe5jlnsWQV'},
# ...

# %%
base_url = 'https://api.spotify.com/v1' #base del endpoint v1:version 1
parameneter = '/7ltDVBr6mKbRvohxheJ9h1'
parametro1 = '/related-artists'
track = '/top-tracks'
resource = '/artists'   # un parámetro
header = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
#response = requests.get(base_url + resource + parameneter + track + '?market=ES', headers = header).json()
#response

# %%
#response.keys()

# %%
#df = pd.DataFrame(response['tracks'])
#df

# %%
response1.keys()
# Out:
# dict_keys(['artists'])

# %%
df1 = pd.DataFrame(response1['artists'])['id']
df1
# Out:
# 0     3Ces1OJeGOVGcUB0wPaPXJ
# 1     4bJh7sMPcVRiqe5jlnsWQV
# 2     5TYxZTjIPqKM8K8NuP9woO
# 3     7rOlQwf8OuFLFQp4aydjBt
# 4     43Hr2FjhVehkROIIEb7EfQ
# 5     4F4pp8NUW08JuXwnoxglpN
# 6     3VHAySZQPlfGlNLslzXYpN
# 7     0jeYkqwckGJoHQhhXwgzk3
# 8     1jB62pOe5WpGiHOBDtKBBG
# 9     1rTUwYS38LkQTlT2fhikch
# 10    2t7vyRN71qtQT18frElAnV
# 11    3Dz4sliAAIVOlALfHW9TtD
# 12    6i3DxIlAqnDkwELLw4aVrx
# 13    3bvfu2KAve4lPHrhEFDZna
# 14    0VZrPa7mWAYXH4CwmYk8Km
# 15    3UZFWMkyLElpRsLPdButSC
# 16    5J7rXWjtn5HzUkJ4Jet8Fr
# 17    3hvDAraTidCTjQHIc4m8P3
# 18    4nXXIxTneJksvGXrlmX8oA
# 19    7n8CEf82NSsckIB7kMwm9d
# Name: id, dtype: object

# %%
list(df1)
# Out:
# ['3Ces1OJeGOVGcUB0wPaPXJ',
#  '4bJh7sMPcVRiqe5jlnsWQV',
#  '5TYxZTjIPqKM8K8NuP9woO',
#  '7rOlQwf8OuFLFQp4aydjBt',
#  '43Hr2FjhVehkROIIEb7EfQ',
#  '4F4pp8NUW08JuXwnoxglpN',
#  '3VHAySZQPlfGlNLslzXYpN',
#  '0jeYkqwckGJoHQhhXwgzk3',
#  '1jB62pOe5WpGiHOBDtKBBG',
#  '1rTUwYS38LkQTlT2fhikch',
#  '2t7vyRN71qtQT18frElAnV',
#  '3Dz4sliAAIVOlALfHW9TtD',
#  '6i3DxIlAqnDkwELLw4aVrx',
#  '3bvfu2KAve4lPHrhEFDZna',
#  '0VZrPa7mWAYXH4CwmYk8Km',
#  '3UZFWMkyLElpRsLPdButSC',
#  '5J7rXWjtn5HzUkJ4Jet8Fr',
#  '3hvDAraTidCTjQHIc4m8P3',
#  '4nXXIxTneJksvGXrlmX8oA',
#  '7n8CEf82NSsckIB7kMwm9d']

# %%
#top_related_tracks = requests.get(base_url + resource + '/' + '3Ces1OJeGOVGcUB0wPaPXJ' + '/top-tracks' + '?market=ES', headers = header).json()
#print(top_related_tracks)

# %%
#top_related_tracks.keys()

# %%
#dftop = pd.DataFrame(top_related_tracks['tracks'])
#df1

# %%
def funcion(lista):
    return lista[0]['name']

# %%
lista_df = []
for i in df1:
    response = requests.get(base_url + resource + '/' + i + '/top-tracks' + '?market=ES', headers=header).json()
    df = pd.DataFrame(response['tracks'])
    df = df[['name', 'id','artists']]
    df['artists'] = df['artists'].apply(funcion)
    lista_df.append(df)
    df = pd.concat(lista_df)
df
# Out:
#                                 name                      id           artists
# 0                           Fanático  3ICLKY1a272eLgTVgMamDt  Maikel Delacalle
# 1                              Usted  3JAuTxQUTSjoV1XsYngT0P        Juan Magán
# 2                       Por La Noche  29sEnpw1KVfOIyMI8sSTse    Mala Rodríguez
# 3   Tengo Un Trato - Remastered 2015  13crLwJf5aEt3R8MKcisou    Mala Rodríguez
# 4                        Mujer Bruja  2o2PFz6MLkKXVDYlzDAVH7       Lola Indigo
# ..                               ...                     ...               ...
# 5              Cuando Estamos Juntas  2xqdyHMfl9OprhTjwnAcwy         BEA PELEA
# 6                     Mi Mejor Amiga  7cmQHz6TVcS9E2i29otQI8         BEA PELEA
# 7                          La + xula  604GKsBg2ZlPJZMcWbrVvF         BEA PELEA
# 8                           Kontakto  6QYJHlZkpeKM9ce6eGgrMG          Kabasaki
# 9                        La Gasolina  5nJTzTpJdh16ndlC9eZgxd         BEA PELEA
#
# [200 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)
